# %% [markdown]
# # DarkSec Threat Intelligence EDA
#
# This notebook is a companion notebook for interactive exploration after the project scripts are run.
#
# Recommended workflow:
# 1. Put raw CICIDS2017 CSV files into `data/raw/`
# 2. Run `python src/data_cleaning.py`
# 3. Load `data/cleaned/cleaned_dataset.csv` for ad hoc analysis

# %%
from pathlib import Path
import pandas as pd

project_root = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd()
cleaned_path = project_root / 'data' / 'cleaned' / 'cleaned_dataset.csv'
df = pd.read_csv(cleaned_path)
df.head()
